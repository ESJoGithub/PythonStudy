# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc

# %%
font_path = "C:\\USERS\\USER\\APPDATA\\LOCAL\\MICROSOFT\\WINDOWS\\FONTS\\NANUMGOTHICCODING.ttf"

font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family=font_name)

# %%
df = pd.read_csv('E:\\Python\\auto-mpg.csv', header=None)

# %%
df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'name']

# %% [markdown]
# ### 연비(mpg)와 차중(weight) 열에 대한 산점도 그리기

# %%
plt.style.use('default')

df.plot(kind = 'scatter', x = 'weight', y = 'mpg', c = 'coral', s = 10, figsize=(10, 5))
plt.title('Scatterplot - mpg vs weight')
plt.show()

# %% [markdown]
# ### 연비(mpg)와 차중(weight) 열, 실린더 개수(cylinders)에 대한 버블차트 그리기

# %%
# 실린더 개수의 상대적 비율을 계산하여 시리즈 생성
cylinders_size = df.cylinders/df.cylinders.max() * 300

cylinders_size.tail()
# Out:
# 393    150.0
# 394    150.0
# 395    150.0
# 396    150.0
# 397    150.0
# Name: cylinders, dtype: float64

# %%
df.plot(kind='scatter', x = 'weight', y = 'mpg', c = 'coral', s = cylinders_size, figsize=(10, 5), alpha = 0.3)
plt.title('Scatter plot: mpg-weight-cylinders')
plt.show()

# %% [markdown]
# ### 그래프를 그림 파일로 저장

# %%
# 디자인 변경 cmap : 컬러맵, c : 값에 따라 다른 색상으로 표현
df.plot(kind='scatter', x = 'weight', y = 'mpg', marker = '+', figsize=(10, 5), 
        cmap='viridis', c = cylinders_size, s = 50, alpha = 0.3)

plt.title('Scatter plot: mpg-weight-cylinders')

plt.savefig("./scatter.png")                                 # 배경 있음
plt.savefig("./scatter_transparent.png", transparent=True)  # 배경을 투명하게 지정

plt.show()
